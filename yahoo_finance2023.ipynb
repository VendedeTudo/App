# %% [markdown]
# <a href="https://colab.research.google.com/github/VendedeTudo/App/blob/main/yahoo_finance2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Pegar Cotações do Yahoo Finance com Python
#
# - pandas_datareader
# - yfinance

# %%
import pandas as pd
import pandas_datareader.data as pdr
import yfinance

yfinance.pdr_override()

# %%
ativos = ["ITUB3.SA", "VALE3.SA", "PETR3.SA", "^BVSP"]

data_inicial = "2023-11-01"
data_final = "2023-11-25"

tabela_cotacoes = pdr.get_data_yahoo(ativos, data_inicial, data_final)["Adj Close"]
display(tabela_cotacoes)
# Out:
# [*********************100%%**********************]  4 of 4 completed
#              ITUB3.SA   PETR3.SA   VALE3.SA     ^BVSP
# Date
# 2023-11-01  23.139999  36.959488  69.628738  115053.0
# 2023-11-03  23.670000  37.268448  70.500092  118160.0
# 2023-11-06  23.920000  37.171898  70.797142  118487.0
# 2023-11-07  24.549999  36.351223  69.391106  119268.0
# 2023-11-08  24.719999  35.491920  69.440605  119099.0
# 2023-11-09  24.820000  36.245018  69.777267  119012.0
# 2023-11-10  25.030001  36.129154  70.846657  120636.0
# 2023-11-13  25.049999  36.940178  70.698128  120376.0
# 2023-11-14  25.200001  37.365002  72.886398  123328.0
# 2023-11-16  25.570000  36.611904  73.371582  124576.0
# 2023-11-17  25.709999  38.156712  73.510208  125062.0
# 2023-11-20  25.799999  38.031197  75.312317  126095.0
# 2023-11-21  25.760000  37.654652  77.134232  125607.0
# 2023-11-22  26.000000  37.689999  74.849998  126035.0
# 2023-11-23  26.200001  37.860001  74.379997  126576.0
# ...
